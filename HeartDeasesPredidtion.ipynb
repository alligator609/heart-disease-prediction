# %% [markdown]
# <a href="https://colab.research.google.com/github/alligator609/heart-disease-prediction/blob/main/HeartDeasesPredidtion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13290456 kB
# MemFree:         7475816 kB
# MemAvailable:   12196604 kB
# Buffers:          365308 kB
# Cached:          4486992 kB
# SwapCached:            0 kB
# Active:           675360 kB
# Inactive:        4793616 kB
# Active(anon):       1268 kB
# Inactive(anon):   617268 kB
# Active(file):     674092 kB
# Inactive(file):  4176348 kB
# Unevictable:          20 kB
# Mlocked:              20 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              8448 kB
# Writeback:             0 kB
# AnonPages:        616980 kB
# Mapped:           351224 kB
# Shmem:              1564 kB
# KReclaimable:     195916 kB
# Slab:             240648 kB
# SReclaimable:     195916 kB
# SUnreclaim:        44732 kB
# KernelStack:        7312 kB
# PageTables:         9320 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645228 kB
# Committed_AS:    3537252 kB
# ...

# %% [markdown]
# # Basic Commands

# %%
! cat /proc/cpuinfo

# %% [markdown]
# # Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data Collection and Processing

# %%
#loading the csv data to a Pandas DataFraame
heart_data = pd.read_csv('https://raw.githubusercontent.com/alligator609/ai-data/main/heart-disease/heart-disease.csv')
heart_data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# # Label Meaning
# 1. age: Represents the age of the individual (integer).
# 2. sex: Indicates the gender of the individual (1 for male, 0 for female).
# 3. cp: chest pain type.
# 4. trestbps: Resting blood pressure.
# 5. chol: Cholesterol in mg/dl
# 6. fbs: Fasting blood sugar in mg/dl.
# 7. restecg: Resting electrocardiographic results.
# 8. thalach: Maximum heart rate.
# 9. exang: Exercise induced angina.
# 10. oldpeak: ST depression induced by exercise relative to rest.
# 11. slope: Slope of the peak exercise ST segment.
# 12. ca: Major vessels (0-3) colored by fluoroscopy.
# 13. thal: Thalassemia

# %% [markdown]
# # print dataset in different way

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# print last 5 rows of the dataset
heart_data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
# number of rows and columns in the data set
heart_data.shape
# Out:
# (1025, 14)

# %%
# getting some info about the data
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# # Value Fixings & Target Fix

# %% [markdown]
# ### check for missing value

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### statistical measures about the data

# %%
heart_data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# ### checking  distribution of the target variable

# %%
heart_data['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %% [markdown]
# 1 ---> Defective heart
# 0 --> healty heart

# %%
X = heart_data.drop(columns='target',axis=1)
Y = heart_data['target']

# %%
print(X)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %% [markdown]
# # Splitting Training Data and Test Data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y, random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (1025, 13) (820, 13) (205, 13)

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Logistic Regeration

# %%
LR_model = LogisticRegression()

# %% [markdown]
# ### training the LogisticRegression Model with training data

# %%
LR_model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
#Accuracy score
# accuracy on training data
X_train_prediction = LR_model.predict(X_train)
training_data_accuracy =accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on training data : ', training_data_accuracy)
# Out:
# Accuracy on training data :  0.8524390243902439

# %%
# accuracy on test data
X_test_prediction = LR_model.predict(X_test)
test_data_accuracy =accuracy_score(X_test_prediction,Y_test)
print('Accuracy on training data : ', test_data_accuracy)
# Out:
# Accuracy on training data :  0.8048780487804879

# %% [markdown]
# ## Random Forent

# %%
# sd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.feature_names_in_ = None
rf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# Applying the model to make a prediction

# %%
X_RF_train_prediction = rf.predict(X_train)
RF_training_data_mse = mean_squared_error(X_RF_train_prediction, Y_train)
print('Mean Squared Error on training data: ', RF_training_data_mse)
# get accuracy
RF_training_data_accuracy = r2_score(X_RF_train_prediction, Y_train)
print('Accuracy on training data: ', RF_training_data_accuracy)
# Out:
# Mean Squared Error on training data:  0.12543448514908595
# Accuracy on training data:  -0.5622184655284002

# %% [markdown]
# # Builidng a predicting sytem

# %%
input_data = (44,1,2,130,233,0,1,179,1,0.4,2,0,2)

# change the input data to a numpy array


input_data_as_numpy_array = np.asarray(input_data)


# reshape the numpy array as we are predicting only one instace
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = LR_model.predict(input_data_reshaped)

print ('LR: predict ', prediction)

if(prediction[0]==0):
  print('LR: heart deases')
else:
  print('LR: Heart is OK')

# predict same data with random forest
RF_prediction = rf.predict(input_data_reshaped)
# print of or not
print ('RF: predict ', RF_prediction)
if(RF_prediction[0]==0):
  print('RF: heart deases')
else:
  print('RF: Heart is OK')
# Out:
# LR: predict  [1]
# LR: Heart is OK
# RF: predict  [0.80518638]
# RF: Heart is OK
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
